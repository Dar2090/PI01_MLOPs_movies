# %% [markdown]
# #### Empezamos importando las librerias necesarias:

# %%
import pandas as pd
import numpy as np
import json
import ast

# %% [markdown]
# #### Cargamos nuestro CSV con el parametro low_memory=False para que no arroje advertencia de lectura de archivos grandes.

# %%
df = pd.read_csv('Datasets/movies_dataset.csv', low_memory=False)
df.head()
# Out:
#    adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en  \
# ...

# %% [markdown]
# #### Eliminamos las columnas que no serán utilizadas, video, imdb_id, adult, original_title, vote_count, poster_path y homepage

# %%
df = df.drop(['adult', 'video', 'imdb_id', 'original_title', 'vote_count', 'poster_path', 'homepage'], axis=1)
df.head()
# Out:
#                                belongs_to_collection    budget
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity
# ...

# %% [markdown]
# #### Buscamos valores nulos en las columnas revenue y budget. Rellenamos con 0 y cambiamos el tipo de dato a float para poder realizar operaciones matematicas mas adelante.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4494 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   production_companies   45463 non-null  object
#  8   production_countries   45463 non-null  object
#  9   release_date           45379 non-null  object
#  10  revenue                45460 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
# ...

# %%
# Rellenamos con 0 los valores nulos:

df['revenue'] = df['revenue'].fillna(0)

# %% [markdown]
# ##### Aca tenemos un problema ya que budget tiene valores alfanumricos y no se pueden pasar a tipo float. Los identificamos y luego los eliminamos.

# %%
df['budget'] = df['budget'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[232], line 1
# ----> 1 df['budget'] = df['budget'].astype(float)
#
# File ~/.local/share/virtualenvs/MLOps_Darwin-PXcmFR4w/lib/python3.9/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
num_budget = pd.to_numeric(df['budget'], errors='coerce')

# Encontrar valores no numéricos

valores_no_numericos = df['budget'][num_budget.isna()]

print(valores_no_numericos)
# Out:
# 19730    /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503    /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587    /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# Name: budget, dtype: object

# %%
# Creamos un filtro para buscar los valores que generan el error:

filtro = df['budget'].str.contains('.jpg')

# Aplicamos el filtro generado con el operador de negacion '~' para invertir el mismo y obtener las columnas que no contengan '.jpg'

df = df[~filtro]

# %%
# Finalmente convertimos el tipo de dato a float

df['budget'] = df['budget'].astype('float')

# %% [markdown]
# ##### Vemos que se eliminan los registros que contienen valores alfanumericos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45463 non-null  float64
#  2   genres                 45463 non-null  object
#  3   id                     45463 non-null  object
#  4   original_language      45452 non-null  object
#  5   overview               44509 non-null  object
#  6   popularity             45460 non-null  object
#  7   production_companies   45460 non-null  object
#  8   production_countries   45460 non-null  object
#  9   release_date           45376 non-null  object
#  10  revenue                45463 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
# ...

# %% [markdown]
# #### Creamos la columna return. Nos enontraremos con valores NaN e inf, los cuales reemplazaremos por 0:

# %%
df['return'] = df['revenue']/df['budget']
df.head()
# Out:
#                                belongs_to_collection      budget
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0  \
# 1                                                NaN  65000000.0
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                NaN  16000000.0
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                                               genres     id original_language
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity
# ...

# %%
df['return'] = df['return'].replace(np.inf, 0)
df['return'] = df['return'].fillna(0)

# %%
df['return'].head(30)
# Out:
# 0     12.451801
# 1      4.043035
# 2      0.000000
# 3      5.090760
# 4      0.000000
# 5      3.123947
# 6      0.000000
# 7      0.000000
# 8      1.838576
# 9      6.072311
# 10     1.739992
# 11     0.000000
# 12     0.000000
# 13     0.310949
# 14     0.102218
# 15     2.232930
# 16     8.181818
# 17     1.075000
# 18     7.079518
# 19     0.590519
# 20     3.805012
# 21     0.000000
# 22     0.606061
# 23     0.000000
# 24    13.833333
# 25     0.000000
# 26     2.283333
# 27     0.000000
# 28     0.096589
# 29     0.000000
# Name: return, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45463 non-null  float64
#  2   genres                 45463 non-null  object
#  3   id                     45463 non-null  object
#  4   original_language      45452 non-null  object
#  5   overview               44509 non-null  object
#  6   popularity             45460 non-null  object
#  7   production_companies   45460 non-null  object
#  8   production_countries   45460 non-null  object
#  9   release_date           45376 non-null  object
#  10  revenue                45463 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
# ...

# %% [markdown]
# #### Transformaremos la columna release_date a datetime con el formato AAAA-mm-dd para luego extraer el anio y crear la nueva columna release_year:

# %% [markdown]
# ##### Convertimos la columna 'fecha' al tipo datetime

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45463 non-null  float64
#  2   genres                 45463 non-null  object
#  3   id                     45463 non-null  object
#  4   original_language      45452 non-null  object
#  5   overview               44509 non-null  object
#  6   popularity             45460 non-null  object
#  7   production_companies   45460 non-null  object
#  8   production_countries   45460 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45463 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
# ...

# %%
df['release_year'] = df.release_date.dt.year
df.head(10)
# Out:
#                                belongs_to_collection      budget
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0  \
# 1                                                NaN  65000000.0
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                NaN  16000000.0
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# 5                                                NaN  60000000.0
# 6                                                NaN  58000000.0
# 7                                                NaN         0.0
# 8                                                NaN  35000000.0
# 9  {'id': 645, 'name': 'James Bond Collection', '...  58000000.0
#
#                                               genres     id original_language
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# ...

# %% [markdown]
# ##### Rellenamos con 0 los valores faltantes y reemplazamos con 0 los inf:

# %%
df['release_year'] = df['release_year'].replace(np.inf, 0)
df['release_year'] = df['release_year'].fillna(0)

# %%
df['release_year'] = df['release_year'].astype('int')

# %% [markdown]
# ##### Verificamos los tipos de datos:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45463 non-null  float64
#  2   genres                 45463 non-null  object
#  3   id                     45463 non-null  object
#  4   original_language      45452 non-null  object
#  5   overview               44509 non-null  object
#  6   popularity             45460 non-null  object
#  7   production_companies   45460 non-null  object
#  8   production_countries   45460 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45463 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
# ...

# %% [markdown]
# #### Ahora vamos a jugar con los datos anidados, vamos a quedarnos con lo que creemos importante de cada columna con datos anidados:

# %%
# Funcion para obtener el los nombre de los objetos anidados de las columnas production_countries, production_countries, genres, spoken_languages, que tienen una estructura similar.

def get_object_names(x):
    try:
        object_list = eval(x)
        object_names = [object_dict['name'] for object_dict in object_list]
        return ', '.join(object_names)
    except:
        return ''

# %%
# Funcion para obtener el los nombre de los objetos anidados de la columna belongs_to_collection

def fetch_name(obj): 
    if isinstance(obj, str) and '{' in obj:
        # print(obj)
        dic = ast.literal_eval(obj)
        return dic['name']

# %%
df['production_countries'] = df['production_countries'].apply(get_object_names)
df['production_companies'] = df['production_companies'].apply(get_object_names)
df['genres'] = df['genres'].apply(get_object_names)
df['spoken_languages'] = df['spoken_languages'].apply(get_object_names)
df['belongs_to_collection'] = df['belongs_to_collection'].apply(fetch_name)

# %%
df.head(5)
# Out:
#             belongs_to_collection      budget                      genres
# 0            Toy Story Collection  30000000.0   Animation, Comedy, Family  \
# 1                            None  65000000.0  Adventure, Fantasy, Family
# 2       Grumpy Old Men Collection         0.0             Romance, Comedy
# 3                            None  16000000.0      Comedy, Drama, Romance
# 4  Father of the Bride Collection         0.0                      Comedy
#
#       id original_language                                           overview
# 0    862                en  Led by Woody, Andy's toys live happily in his ...  \
# 1   8844                en  When siblings Judy and Peter discover an encha...
# 2  15602                en  A family wedding reignites the ancient feud be...
# 3  31357                en  Cheated on, mistreated and stepped on, the wom...
# 4  11862                en  Just when George Banks has recovered from his ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45463 non-null  float64
#  2   genres                 45463 non-null  object
#  3   id                     45463 non-null  object
#  4   original_language      45452 non-null  object
#  5   overview               44509 non-null  object
#  6   popularity             45460 non-null  object
#  7   production_companies   45463 non-null  object
#  8   production_countries   45463 non-null  object
#  9   release_date           45376 non-null  datetime64[ns]
#  10  revenue                45463 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45463 non-null  object
#  13  status                 45379 non-null  object
# ...

# %% [markdown]
# #### Contamos valores vacios de las columnas "production_companies", "production_countries" y rellenamos con "unknown":

# %%
# Contamos la cantidad de valores NaN o NA
cantidad_vacios_pcountries = sum(df["production_countries"].str.strip() == "")
cantidad_vacios_pcompanies = sum(df["production_companies"].str.strip() == "")

print(f"Cantidad de valores vacios production_countries: {cantidad_vacios_pcountries}, production_companies: {cantidad_vacios_pcompanies}")
# Out:
# Cantidad de valores vacios production_countries: 0, production_companies: 0

# %%
# Rellenamos los valores vacios con la cadena "unknown"
df["production_countries"].replace("", "unknown", inplace=True)
df["production_companies"].replace("", "unknown", inplace=True)

# %% [markdown]
# ##### Exportamos el nuevo dataframe:

# %%
df.to_csv('Datasets/movies_transformado.csv', index=False)

# %% [markdown]
# #### Creamos un nuevo df a partir del original y lo exportamos a csv para ser consumido por las funciones:
#
# ##### Nos quedamos con las columnas necesarias para que las funciones obtengas los valores solicitados.

# %%
df_movies = df.loc[:, ['belongs_to_collection', 'title', 'production_companies', 'production_countries', 'release_date', 'release_year', 'budget', 'revenue', 'return']]
df_movies.head(5)
# Out:
#             belongs_to_collection                        title
# 0            Toy Story Collection                    Toy Story  \
# 1                            None                      Jumanji
# 2       Grumpy Old Men Collection             Grumpier Old Men
# 3                            None            Waiting to Exhale
# 4  Father of the Bride Collection  Father of the Bride Part II
#
#                                 production_companies
# 0                            Pixar Animation Studios  \
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures
#
#        production_countries release_date  release_year      budget
# 0  United States of America   1995-10-30          1995  30000000.0  \
# 1  United States of America   1995-12-15          1995  65000000.0
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45463 entries, 0 to 45465
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   title                  45460 non-null  object
#  2   production_companies   45463 non-null  object
#  3   production_countries   45463 non-null  object
#  4   release_date           45376 non-null  datetime64[ns]
#  5   release_year           45463 non-null  int64
#  6   budget                 45463 non-null  float64
#  7   revenue                45463 non-null  float64
#  8   return                 45463 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 3.5+ MB

# %%
df_movies.to_csv('Datasets/movies_dataset_red.csv', index=False)

# %% [markdown]
# #### Creamos las funciones necesarias para ser usadas por nuestra API:

# %% [markdown]
# ##### Importamos las librerias necesarias:

# %%
import calendar

# %% [markdown]
# #### Cargamos nuestro nuevo CSV a modo de prueba y verificamos la integridad de los datos y el tipo de dato.

# %%
df_red = pd.read_csv('Datasets/movies_dataset_red.csv', low_memory=False)
df_red.head()
# Out:
#             belongs_to_collection                        title
# 0            Toy Story Collection                    Toy Story  \
# 1                             NaN                      Jumanji
# 2       Grumpy Old Men Collection             Grumpier Old Men
# 3                             NaN            Waiting to Exhale
# 4  Father of the Bride Collection  Father of the Bride Part II
#
#                                 production_companies
# 0                            Pixar Animation Studios  \
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures
#
#        production_countries release_date  release_year      budget
# 0  United States of America   1995-10-30          1995  30000000.0  \
# 1  United States of America   1995-12-15          1995  65000000.0
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   title                  45460 non-null  object
#  2   production_companies   45463 non-null  object
#  3   production_countries   45463 non-null  object
#  4   release_date           45376 non-null  object
#  5   release_year           45463 non-null  int64
#  6   budget                 45463 non-null  float64
#  7   revenue                45463 non-null  float64
#  8   return                 45463 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.1+ MB

# %%
# Se ingresa el mes y la funcion retorna la cantidad de peliculas que se estrenaron ese mes historicamente

def peliculas_mes(mes:str):
    return {'mes':mes, 'cantidad':respuesta}

# %%
def peliculas_mes(mes: str) -> dict:
    # Diccionario para hacer la traducción de nombres de mes de español a inglés
    meses_dict = {"enero":"January", "febrero":"February", "marzo":"March", "abril":"April", "mayo":"May", "junio":"June",
                  "julio":"July", "agosto":"August", "septiembre":"September", "octubre":"October", "noviembre":"November",
                  "diciembre":"December"}
    
    # Convierte la columna "release_date" a formato de fecha
    df_red["release_date"] = pd.to_datetime(df_red["release_date"], errors="coerce")

    # Traduce el nombre de mes ingresado a su equivalente en inglés
    mes_en = meses_dict.get(mes.lower(), None)
    if mes_en is None:
        return {"Error": "El mes ingresado no es válido"}

    # Filtra las películas que se estrenaron en el mes especificado
    peliculas_filtradas = df_red[df_red["release_date"].dt.month == pd.to_datetime(mes_en, format="%B").month]

    # Cuenta la cantidad de películas filtradas
    cantidad_peliculas = len(peliculas_filtradas)

    # Traduce el nombre del mes en inglés de vuelta a español
    mes_es = [key for key, value in meses_dict.items() if value == mes_en][0]

    return {"mes": mes_es.capitalize(), 
            "cantidad": cantidad_peliculas}

# %%
pelis_mes = peliculas_mes("Enero")
pelis_mes
# Out:
# {'mes': 'Enero', 'cantidad': 5912}

# %%
# Se ingresa el dia y la funcion retorna la cantidad de peliculas que se estrenaron ese dia historicamente

def peliculas_dia(dia:str):
    return {'dia':dia, 'cantidad':respuesta}

# %%
def peliculas_dia(dia: str) -> dict:
  
    dia_num = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo'].index(dia)

    # Convertimos la columna 'release_date' a datetime (just in case)
    df_red['release_date'] = pd.to_datetime(df_red['release_date'], format='%Y-%m-%d')

    # Filtramos películas que se estrenaron en el día de la semana dado
    peliculas_en_dia = df_red[df_red['release_date'].dt.weekday == dia_num]

    # Filtramos películas que tengan una fecha de estreno válida
    peliculas_con_fecha_valida = peliculas_en_dia[peliculas_en_dia['release_date'].notnull()]

    cantidad = peliculas_con_fecha_valida.shape[0]

    # Retornar un diccionario con el día y la cantidad de películas
    return {'dia': dia, 
            'cantidad': cantidad}

# %%
pelis = peliculas_dia("Lunes")
pelis
# Out:
# {'dia': 'Lunes', 'cantidad': 3503}

# %%
# Se ingresa la franquicia, retornando la cantidad de peliculas, ganancia total y promedio

def franquicia(franquicia:str):
    return {'franquicia':franquicia, 'cantidad':respuesta, 'ganancia_total':respuesta, 'ganancia_promedio':respuesta}

# %%
def franquicia(franquicia: str) -> dict:
   
    # Filtramos las películas que pertenecen a la franquicia solicitada
    peliculas_filtradas = df_red[df_red["belongs_to_collection"] == franquicia]

    # Contamos la cantidad de películas
    cantidad_peliculas = len(peliculas_filtradas)

    # Calculamos la ganancia total
    ganancia_total = peliculas_filtradas["revenue"].sum()

    # Calculamos la ganancia promedio
    ganancia_promedio = ganancia_total / cantidad_peliculas

    return {'franquicia': franquicia,
            'cantidad': cantidad_peliculas,
            'ganancia_total': ganancia_total,
            'ganancia_promedio': ganancia_promedio}

# %%
df_movies.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                  None
# 2             Grumpy Old Men Collection
# 3                                  None
# 4        Father of the Bride Collection
#                       ...
# 45461                              None
# 45462                              None
# 45463                              None
# 45464                              None
# 45465                              None
# Name: belongs_to_collection, Length: 45463, dtype: object

# %%
franqui = franquicia("Toy Story Collection")
franqui
# Out:
# {'franquicia': 'Toy Story Collection',
#  'cantidad': 3,
#  'ganancia_total': 1937890605.0,
#  'ganancia_promedio': 645963535.0}

# %%
# Ingresas el pais, retornando la cantidad de peliculas producidas en el mismo

def peliculas_pais(pais:str):
    
    return {'pais':pais, 'cantidad':respuesta}

# %%
def peliculas_pais(pais: str) -> dict:

    # Filtramos las películas que se produjeron en el país solicitado
    peliculas_filtradas = df_red[df_red["production_countries"].str.contains(pais)]

    # Contamos la cantidad de películas
    cantidad_peliculas = len(peliculas_filtradas)

    return {'pais': pais,
            'cantidad': cantidad_peliculas}

# %%
pelis_pais = peliculas_pais("United States of America")
pelis_pais
# Out:
# {'pais': 'United States of America', 'cantidad': 21153}

# %%
#Ingresas la productora, retornando la ganancia total y la cantidad de peliculas que produjeron

def productoras(productora:str):
    
    return {'productora':productora, 'ganancia_total':respuesta, 'cantidad':respuesta}

# %%
def productoras(productora: str):
    # Crear subconjunto del DataFrame original para la productora seleccionada
    subset = df_red[df_red["production_companies"].str.contains(productora, na=False)]

    # Obtener la ganancia total y la cantidad de películas producidas por la productora seleccionada
    ganancia_total = subset["revenue"].sum()
    cantidad = len(subset)

    # Retornar un diccionario con los resultados
    return {"productora": productora, 
            "ganancia_total": ganancia_total, 
            "cantidad": cantidad}

# %%
df['production_companies']
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures, Teitler Film, Interscope Com...
# 2                             Warner Bros., Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4               Sandollar Productions, Touchstone Pictures
#                                ...
# 45461                                              unknown
# 45462                                          Sine Olivia
# 45463                              American World Pictures
# 45464                                            Yermoliev
# 45465                                              unknown
# Name: production_companies, Length: 45463, dtype: object

# %%
productora_ganancia = productoras('Pixar Animation Studios')
productora_ganancia
# Out:
# {'productora': 'Pixar Animation Studios',
#  'ganancia_total': 8512533734.0,
#  'cantidad': 52}

# %%
# Ingresas la pelicula, retornando la inversion, la ganancia, el retorno y el año en el que se lanzo

def retorno(pelicula:str):

    return {'pelicula':pelicula, 
            'inversion':respuesta, 'ganacia':respuesta,'retorno':respuesta, 'anio':respuesta}

# %%
def retorno(pelicula: str):
    # Crear subconjunto del DataFrame original para la película seleccionada
    subset = df_red[df_red["title"] == pelicula]

    # Verificar si el subconjunto tiene al menos un elemento
    if len(subset) == 0:
        return {'error': 'Película no encontrada'}

    # Obtener la inversión, ganancia y año de lanzamiento de la película seleccionada
    inversion = subset["budget"].values[0]
    ganancia = subset["revenue"].values[0] - inversion
    anio = str(subset["release_year"].values[0])

    # Obtener el retorno de la película seleccionada a partir de la columna "return"
    retorno = subset["return"].values[0]

    # Retornar un diccionario con los resultados
    return {'pelicula': pelicula, 
            'inversion': inversion, 
            'ganancia': ganancia, 
            'retorno': retorno, 
            'anio': anio}

# %%
peli = retorno("Toy Story")
peli
# Out:
# {'pelicula': 'Toy Story',
#  'inversion': 30000000.0,
#  'ganancia': 343554033.0,
#  'retorno': 12.4518011,
#  'anio': 1995}
